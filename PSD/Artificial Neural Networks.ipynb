# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
path = 'traindats.csv'
data = pd.read_csv(path)
data.head()
# Out:
#    PulseNo  TotalArea  TailArea Classification
# 0        1       7616      4568        Neutron
# 1        2       7616      4584        Neutron
# 2        3       7616      4860        Neutron
# 3        4       7616      4548        Neutron
# 4        5       7616      4344        Neutron

# %%
from sklearn.preprocessing import LabelEncoder
lab_encod = LabelEncoder()
data['Classification_encod'] = lab_encod.fit_transform(data['Classification'])
data = data.drop(['Classification'],axis = 'columns')
data.head()
# Out:
#    PulseNo  TotalArea  TailArea  Classification_encod
# 0        1       7616      4568                     1
# 1        2       7616      4584                     1
# 2        3       7616      4860                     1
# 3        4       7616      4548                     1
# 4        5       7616      4344                     1

# %%
x = data.iloc[:,1:]
x = x.drop(['Classification_encod'],axis = 'columns')
y = data.iloc[:,-1]
scaler = StandardScaler()
x = scaler.fit_transform(x)
x = pd.DataFrame(x,columns = ['TotalArea','TailArea'])
x = x.values
y = y.values

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,
                                                 random_state = 42)
print("Training data shape",x_train.shape)
print("Test data shape",x_test.shape)
# Out:
# Training data shape (43590, 2)
# Test data shape (14531, 2)

# %%
def accuracy_fn(y_pred,y_test):
    accuracy = 0
    for i in range(len(y_pred)):
        if y_pred[i]==y_test[i]:
            accuracy  = accuracy + 1
    
    return accuracy/len(y_pred)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
#Classification using Artificial Neural Networks

def build_model1(input_node):
    inputs = layers.Input(shape = input_node, name = "input",dtype=np.float32)
    x = tf.keras.layers.Dense(128,activation='relu',name='hidden1')(inputs)
    x = layers.Dropout(0.1)(x)
    outputs = tf.keras.layers.Dense(2,activation='softmax',name='output')(x)
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model

def build_model2(input_node):
    inputs = layers.Input(shape = input_node, name = "input",dtype=np.float32)
    x = tf.keras.layers.Dense(256,activation='relu',name='hidden1')(inputs)
    x = layers.Dropout(0.1)(x)
    outputs = tf.keras.layers.Dense(2,activation='softmax',name='output')(x)
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model


def build_model3(input_node):
    inputs = layers.Input(shape = input_node, name = "input",dtype=np.float32)
    x = tf.keras.layers.Dense(128,activation='relu',name='hidden1')(inputs)
    x = layers.Dropout(0.1)(x)
    x = tf.keras.layers.Dense(128,activation='relu',name='hidden2')(x)
    x = layers.Dropout(0.1)(x)
    outputs = tf.keras.layers.Dense(2,activation='softmax',name='output')(x)
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model

def build_model4(input_node):
    inputs = layers.Input(shape = input_node, name = "input",dtype=np.float32)
    x = tf.keras.layers.Dense(128,activation='relu',name='hidden1')(inputs)
    x = layers.Dropout(0.1)(x)
    x = tf.keras.layers.Dense(256,activation='relu',name='hidden2')(x)
    x = layers.Dropout(0.1)(x)
    outputs = tf.keras.layers.Dense(2,activation='softmax',name='output')(x)
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model


def build_model5(input_node):
    inputs = layers.Input(shape = input_node, name = "input",dtype=np.float32)
    x = tf.keras.layers.Dense(128,activation='relu',name='hidden1')(inputs)
    x = layers.Dropout(0.1)(x)
    x = tf.keras.layers.Dense(512,activation='relu',name='hidden2')(x)
    x = layers.Dropout(0.1)(x)
    x = tf.keras.layers.Dense(256,activation='relu',name='hidden3')(x)
    x = layers.Dropout(0.1)(x)
    outputs = tf.keras.layers.Dense(2,activation='softmax',name='output')(x)
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model

def build_model6(input_node):
    inputs = layers.Input(shape = input_node, name = "input",dtype=np.float32)
    x = tf.keras.layers.Dense(128,activation='relu',name='hidden1')(inputs)
    x = layers.Dropout(0.1)(x)
    x = tf.keras.layers.Dense(256,activation='relu',name='hidden2')(x)
    x = layers.Dropout(0.1)(x)
    x = tf.keras.layers.Dense(256,activation='relu',name='hidden3')(x)
    x = layers.Dropout(0.1)(x)
    outputs = tf.keras.layers.Dense(2,activation='softmax',name='output')(x)
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model

def build_model7(input_node):
    inputs = layers.Input(shape = input_node, name = "input",dtype=np.float32)
    x = tf.keras.layers.Dense(128,activation='relu',name='hidden1')(inputs)
    x = layers.Dropout(0.1)(x)
    x = tf.keras.layers.Dense(256,activation='relu',name='hidden2')(x)
    x = layers.Dropout(0.1)(x)
    x = tf.keras.layers.Dense(256,activation='relu',name='hidden3')(x)
    x = layers.Dropout(0.1)(x)
    x = tf.keras.layers.Dense(128,activation='relu',name='hidden4')(x)
    x = layers.Dropout(0.1)(x)
    outputs = tf.keras.layers.Dense(2,activation='softmax',name='output')(x)
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model



def build_model8(input_node):
    inputs = layers.Input(shape = input_node, name = "input",dtype=np.float32)
    x = tf.keras.layers.Dense(128,activation='relu',name='hidden1')(inputs)
    x = layers.Dropout(0.1)(x)
    x = tf.keras.layers.Dense(256,activation='relu',name='hidden2')(x)
    x = layers.Dropout(0.1)(x)
    x = tf.keras.layers.Dense(512,activation='relu',name='hidden3')(x)
    x = layers.Dropout(0.1)(x)
    x = tf.keras.layers.Dense(256,activation='relu',name='hidden4')(x)
    x = layers.Dropout(0.1)(x)
    outputs = tf.keras.layers.Dense(2,activation='softmax',name='output')(x)
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model

# %%
accuracy_list = []

num_epochs = 10
batch_size = 264

num_feature = 2
model1 = build_model1(num_feature)
model1.summary()
model1.fit(x_train,y_train,batch_size = batch_size,
         epochs = num_epochs)

y_pred_hot = model1.predict(x_test)
y_pred_temp = np.array(y_pred_hot.argmax(axis=1))
temp_accuracy = accuracy_fn(y_pred_temp,y_test)
accuracy_list.append(["model1",temp_accuracy])

###########################################################################################################

model2 = build_model2(num_feature)
model2.summary()
model2.fit(x_train,y_train,batch_size = batch_size,
         epochs = num_epochs)

y_pred_hot = model2.predict(x_test)
y_pred_temp = np.array(y_pred_hot.argmax(axis=1))
temp_accuracy = accuracy_fn(y_pred_temp,y_test)
accuracy_list.append(["model2",temp_accuracy])

#############################################################################################################

model3 = build_model3(num_feature)
model3.summary()
model3.fit(x_train,y_train,batch_size = batch_size,
         epochs = num_epochs)

y_pred_hot = model3.predict(x_test)
y_pred_temp = np.array(y_pred_hot.argmax(axis=1))
temp_accuracy = accuracy_fn(y_pred_temp,y_test)
accuracy_list.append(["model3",temp_accuracy])

#############################################################################################################

model4 = build_model4(num_feature)
model4.summary()
model4.fit(x_train,y_train,batch_size = batch_size,
         epochs = num_epochs)

y_pred_hot = model4.predict(x_test)
y_pred_temp = np.array(y_pred_hot.argmax(axis=1))
temp_accuracy = accuracy_fn(y_pred_temp,y_test)
accuracy_list.append(["model4",temp_accuracy])

#################################################################################################################

model5 = build_model5(num_feature)
model5.summary()
model5.fit(x_train,y_train,batch_size = batch_size,
         epochs = num_epochs)

y_pred_hot = model5.predict(x_test)
y_pred_temp = np.array(y_pred_hot.argmax(axis=1))
temp_accuracy = accuracy_fn(y_pred_temp,y_test)
accuracy_list.append(["model5",temp_accuracy])


###################################################################################################################

model6 = build_model6(num_feature)
model6.summary()
model6.fit(x_train,y_train,batch_size = batch_size,
         epochs = num_epochs)

y_pred_hot = model6.predict(x_test)
y_pred_temp = np.array(y_pred_hot.argmax(axis=1))
temp_accuracy = accuracy_fn(y_pred_temp,y_test)
accuracy_list.append(["model6",temp_accuracy])

#############################################################################################################

model7 = build_model7(num_feature)
model7.summary()
model7.fit(x_train,y_train,batch_size = batch_size,
         epochs = num_epochs)

y_pred_hot = model7.predict(x_test)
y_pred_temp = np.array(y_pred_hot.argmax(axis=1))
temp_accuracy = accuracy_fn(y_pred_temp,y_test)
accuracy_list.append(["model7",temp_accuracy])

#############################################################################################################

model8 = build_model8(num_feature)
model8.summary()
model8.fit(x_train,y_train,batch_size = batch_size,
         epochs = num_epochs)

y_pred_hot = model8.predict(x_test)
y_pred_temp = np.array(y_pred_hot.argmax(axis=1))
temp_accuracy = accuracy_fn(y_pred_temp,y_test)
accuracy_list.append(["model8",temp_accuracy])
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2)]               0
# _________________________________________________________________
# hidden1 (Dense)              (None, 128)               384
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 258
# =================================================================
# Total params: 642
# Trainable params: 642
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 166/166 [==============================] - 1s 2ms/step - loss: 0.4279 - accuracy: 0.8185
# Epoch 2/10
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2856 - accuracy: 0.9051
# Epoch 3/10
# 166/166 [==============================] - 0s 2ms/step - loss: 0.2124 - accuracy: 0.9193
# Epoch 4/10
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1705 - accuracy: 0.9329
# Epoch 5/10
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1411 - accuracy: 0.9450
# Epoch 6/10
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1201 - accuracy: 0.9546
# Epoch 7/10
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1056 - accuracy: 0.9598
# Epoch 8/10
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0937 - accuracy: 0.9661
# Epoch 9/10
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0846 - accuracy: 0.9706
# Epoch 10/10
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0771 - accuracy: 0.9748
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2)]               0
# _________________________________________________________________
# hidden1 (Dense)              (None, 256)               768
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 514
# =================================================================
# Total params: 1,282
# Trainable params: 1,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 166/166 [==============================] - 1s 2ms/step - loss: 0.3540 - accuracy: 0.8755
# Epoch 2/10
# 166/166 [==============================] - 0s 2ms/step - loss: 0.2087 - accuracy: 0.9205
# Epoch 3/10
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1514 - accuracy: 0.9394: 0s - loss: 0.1527 - accuracy: 0.93
# Epoch 4/10
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1191 - accuracy: 0.9537
# Epoch 5/10
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0985 - accuracy: 0.9634
# Epoch 6/10
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0838 - accuracy: 0.9708
# Epoch 7/10
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0734 - accuracy: 0.9756
# Epoch 8/10
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 0.9789
# Epoch 9/10
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0600 - accuracy: 0.9826
# Epoch 10/10
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0551 - accuracy: 0.9844
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2)]               0
# _________________________________________________________________
# hidden1 (Dense)              (None, 128)               384
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 258
# =================================================================
# Total params: 17,154
# Trainable params: 17,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 166/166 [==============================] - 1s 2ms/step - loss: 0.2254 - accuracy: 0.9184
# Epoch 2/10
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0709 - accuracy: 0.9747
# Epoch 3/10
# 166/166 [==============================] - 0s 3ms/step - loss: 0.0486 - accuracy: 0.9831
# Epoch 4/10
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0376 - accuracy: 0.9870
# Epoch 5/10
# 166/166 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 0.9896
# Epoch 6/10
# 166/166 [==============================] - 0s 3ms/step - loss: 0.0258 - accuracy: 0.9916
# Epoch 7/10
# 166/166 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.9926
# Epoch 8/10
# 166/166 [==============================] - 0s 3ms/step - loss: 0.0197 - accuracy: 0.9934
# Epoch 9/10
# 166/166 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 0.9929
# Epoch 10/10
# 166/166 [==============================] - 0s 3ms/step - loss: 0.0183 - accuracy: 0.9931
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2)]               0
# _________________________________________________________________
# hidden1 (Dense)              (None, 128)               384
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 514
# =================================================================
# Total params: 33,922
# Trainable params: 33,922
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 166/166 [==============================] - 1s 3ms/step - loss: 0.2091 - accuracy: 0.9222
# Epoch 2/10
# 166/166 [==============================] - 1s 3ms/step - loss: 0.0664 - accuracy: 0.9757
# Epoch 3/10
# 166/166 [==============================] - 1s 4ms/step - loss: 0.0459 - accuracy: 0.9837
# Epoch 4/10
# 166/166 [==============================] - 1s 5ms/step - loss: 0.0341 - accuracy: 0.9894
# Epoch 5/10
# 166/166 [==============================] - 1s 5ms/step - loss: 0.0281 - accuracy: 0.9910
# Epoch 6/10
# 166/166 [==============================] - 1s 5ms/step - loss: 0.0245 - accuracy: 0.9916
# Epoch 7/10
# 166/166 [==============================] - 1s 4ms/step - loss: 0.0252 - accuracy: 0.9904
# Epoch 8/10
# 166/166 [==============================] - 1s 4ms/step - loss: 0.0204 - accuracy: 0.9927
# Epoch 9/10
# 166/166 [==============================] - 1s 3ms/step - loss: 0.0191 - accuracy: 0.9927
# Epoch 10/10
# 166/166 [==============================] - 1s 3ms/step - loss: 0.0168 - accuracy: 0.9939
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2)]               0
# _________________________________________________________________
# hidden1 (Dense)              (None, 128)               384
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden2 (Dense)              (None, 512)               66048
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden3 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 514
# =================================================================
# Total params: 198,274
# Trainable params: 198,274
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 166/166 [==============================] - 2s 8ms/step - loss: 0.1300 - accuracy: 0.9511
# Epoch 2/10
# 166/166 [==============================] - 1s 8ms/step - loss: 0.0390 - accuracy: 0.9842
# Epoch 3/10
# 166/166 [==============================] - 1s 7ms/step - loss: 0.0319 - accuracy: 0.9882
# Epoch 4/10
# 166/166 [==============================] - 1s 7ms/step - loss: 0.0214 - accuracy: 0.9909
# Epoch 5/10
# 166/166 [==============================] - 1s 7ms/step - loss: 0.0252 - accuracy: 0.9896
# Epoch 6/10
# 166/166 [==============================] - 1s 7ms/step - loss: 0.0169 - accuracy: 0.9930
# Epoch 7/10
# 166/166 [==============================] - 1s 7ms/step - loss: 0.0186 - accuracy: 0.9921
# Epoch 8/10
# 166/166 [==============================] - 1s 7ms/step - loss: 0.0151 - accuracy: 0.9938
# Epoch 9/10
# 166/166 [==============================] - 1s 7ms/step - loss: 0.0177 - accuracy: 0.9927
# Epoch 10/10
# 166/166 [==============================] - 1s 7ms/step - loss: 0.0144 - accuracy: 0.9939
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2)]               0
# _________________________________________________________________
# hidden1 (Dense)              (None, 128)               384
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# hidden3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 514
# =================================================================
# Total params: 99,714
# Trainable params: 99,714
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 166/166 [==============================] - 1s 5ms/step - loss: 0.1550 - accuracy: 0.9408
# Epoch 2/10
# 166/166 [==============================] - 1s 7ms/step - loss: 0.0448 - accuracy: 0.9819
# Epoch 3/10
# 166/166 [==============================] - 1s 7ms/step - loss: 0.0333 - accuracy: 0.9868
# Epoch 4/10
# 166/166 [==============================] - 1s 6ms/step - loss: 0.0242 - accuracy: 0.9897
# Epoch 5/10
# 166/166 [==============================] - 1s 6ms/step - loss: 0.0214 - accuracy: 0.9915
# Epoch 6/10
# 166/166 [==============================] - 1s 5ms/step - loss: 0.0188 - accuracy: 0.9919
# Epoch 7/10
# 166/166 [==============================] - 1s 5ms/step - loss: 0.0154 - accuracy: 0.9939
# Epoch 8/10
# 166/166 [==============================] - 1s 5ms/step - loss: 0.0142 - accuracy: 0.9941
# Epoch 9/10
# 166/166 [==============================] - 1s 5ms/step - loss: 0.0156 - accuracy: 0.9934
# Epoch 10/10
# 166/166 [==============================] - 1s 5ms/step - loss: 0.0138 - accuracy: 0.9940
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2)]               0
# _________________________________________________________________
# hidden1 (Dense)              (None, 128)               384
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 128)               0
# _________________________________________________________________
# hidden2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# hidden3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# hidden4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 258
# =================================================================
# Total params: 132,354
# Trainable params: 132,354
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 166/166 [==============================] - 1s 6ms/step - loss: 0.1431 - accuracy: 0.9447
# Epoch 2/10
# 166/166 [==============================] - 1s 6ms/step - loss: 0.0380 - accuracy: 0.9853
# Epoch 3/10
# 166/166 [==============================] - 1s 6ms/step - loss: 0.0315 - accuracy: 0.9876
# Epoch 4/10
# 166/166 [==============================] - 1s 6ms/step - loss: 0.0243 - accuracy: 0.9897
# Epoch 5/10
# 166/166 [==============================] - 1s 6ms/step - loss: 0.0205 - accuracy: 0.9918
# Epoch 6/10
# 166/166 [==============================] - 1s 6ms/step - loss: 0.0218 - accuracy: 0.9912
# Epoch 7/10
# 166/166 [==============================] - 1s 6ms/step - loss: 0.0158 - accuracy: 0.9935
# Epoch 8/10
# 166/166 [==============================] - 1s 6ms/step - loss: 0.0175 - accuracy: 0.9928
# Epoch 9/10
# 166/166 [==============================] - 1s 6ms/step - loss: 0.0178 - accuracy: 0.9930
# Epoch 10/10
# 166/166 [==============================] - 1s 6ms/step - loss: 0.0147 - accuracy: 0.9940
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2)]               0
# _________________________________________________________________
# hidden1 (Dense)              (None, 128)               384
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 128)               0
# _________________________________________________________________
# hidden2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 256)               0
# _________________________________________________________________
# hidden3 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 512)               0
# _________________________________________________________________
# hidden4 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 256)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 514
# =================================================================
# Total params: 296,834
# Trainable params: 296,834
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 166/166 [==============================] - 2s 10ms/step - loss: 0.1320 - accuracy: 0.9490
# Epoch 2/10
# 166/166 [==============================] - 2s 10ms/step - loss: 0.0371 - accuracy: 0.9849
# Epoch 3/10
# 166/166 [==============================] - 2s 9ms/step - loss: 0.0259 - accuracy: 0.9890
# Epoch 4/10
# 166/166 [==============================] - 2s 9ms/step - loss: 0.0228 - accuracy: 0.9904
# Epoch 5/10
# 166/166 [==============================] - 1s 9ms/step - loss: 0.0202 - accuracy: 0.9918
# Epoch 6/10
# 166/166 [==============================] - 2s 9ms/step - loss: 0.0221 - accuracy: 0.9899
# Epoch 7/10
# 166/166 [==============================] - 2s 9ms/step - loss: 0.0158 - accuracy: 0.9930
# Epoch 8/10
# 166/166 [==============================] - 2s 9ms/step - loss: 0.0134 - accuracy: 0.9942
# Epoch 9/10
# 166/166 [==============================] - 2s 10ms/step - loss: 0.0143 - accuracy: 0.9938
# Epoch 10/10
# 166/166 [==============================] - 2s 9ms/step - loss: 0.0172 - accuracy: 0.9927

# %%
model_names = []
accuracy_of_model = []
for model_name, accuracy in accuracy_list:
    print("MODEL NAME: ",model_name," ","Accuracy: ",accuracy)
    model_names.append(model_name)
    accuracy_of_model.append(accuracy)
# Out:
# MODEL NAME:  model1   Accuracy:  0.9730920101851215
# MODEL NAME:  model2   Accuracy:  0.9883008739935311
# MODEL NAME:  model3   Accuracy:  0.9927740692312986
# MODEL NAME:  model4   Accuracy:  0.9949074392677724
# MODEL NAME:  model5   Accuracy:  0.9923611589016585
# MODEL NAME:  model6   Accuracy:  0.9913288830775583
# MODEL NAME:  model7   Accuracy:  0.9891955130410846
# MODEL NAME:  model8   Accuracy:  0.9971784460807928

# %%
plt.scatter(model_names,accuracy_of_model)

# %%
best_ann_model = model8
y_pred = model7.predict(x_test)
y_pred = np.array(y_pred_hot.argmax(axis=1))
accuracy_ann = accuracy_fn(y_pred,y_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
confusion_mat = confusion_matrix(y_test,y_pred)
print(confusion_mat)
# Out:
# [[10852    13]
#  [   28  3638]]

# %%
classification_repo = classification_report(y_test,y_pred)
print(classification_repo)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     10865
#            1       1.00      0.99      0.99      3666
#
#     accuracy                           1.00     14531
#    macro avg       1.00      1.00      1.00     14531
# weighted avg       1.00      1.00      1.00     14531

# %%
accuracy_ann = np.max(accuracy_of_model)
print("Accuracy using Artificial Neural Networks",accuracy_ann)
# Out:
# Accuracy using Artificial Neural Networks 0.9971784460807928

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def build_model8(input_node):
    inputs = layers.Input(shape = input_node, name = "input",dtype=np.float32)
    x = tf.keras.layers.Dense(128,activation='relu',name='hidden1')(inputs)
    x = layers.Dropout(0.1)(x)
    x = tf.keras.layers.Dense(256,activation='relu',name='hidden2')(x)
    x = layers.Dropout(0.1)(x)
    x = tf.keras.layers.Dense(512,activation='relu',name='hidden3')(x)
    x = layers.Dropout(0.1)(x)
    x = tf.keras.layers.Dense(256,activation='relu',name='hidden4')(x)
    x = layers.Dropout(0.1)(x)
    outputs = tf.keras.layers.Dense(2,activation='softmax',name='output')(x)
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model
